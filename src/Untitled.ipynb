# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\ben\appdata\local\programs\python\python310\lib\site-packages (1.22.4)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Ben\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from matplotlib import pyplot as plt
import numpy as np
x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Ben's Random Data")
plt.show()

# %%
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Ben's Random Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 x, y, scale = np.random.randn(3, 100)
# ----> 2 fig, ax = plt.su()
#       4 # Map each onto a scatterplot we'll create with Matplotlib
#       5 ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'su'

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(50000)
y = 1.2 * x + np.random.randn(50000) / 3

# plot:
fig, ax = plt.subplots()

ax.hexbin(x, y, gridsize=20)

ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.show()
